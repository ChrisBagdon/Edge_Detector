# %%
# %load_ext autoreload
# %autoreload 2
import edge_detector
import threshold_tester

"""Notebook for testing methods as they are built"""
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 'Notebook for testing methods as they are built'

# %%
edge_detector.write_edges("data/Image_5.jpg", 50, 200, "Output/test.png")

# %%
threshold_tester.test_edges("data/Image_1.png", 50, 200)
# Out:
# Min: 50
#  Max: 200
